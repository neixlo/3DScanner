# %%
import scanner

# %%
sc = scanner.scanner()
# Out:
# Camera initialized.
#
#
#
# Connection to Arduino established.
#
# Serial<id=0x7f53441bdb70, open=True>(port='/dev/ttyUSB0', baudrate=115200, bytesize=8, parity='N', stopbits=1, timeout=1, xonxoff=False, rtscts=False, dsrdtr=False)
#
#
# b''
# b'Commands step by step guide\r\n'
# b'Type hello -sends TB6600 Tester Ready \r\n'
# b'Type xon  -turns TB6600 on\r\n'
# b'Type x+Number(0-60000) eg x1904 -to set next move steps\r\n'
# b'Type mx -to make motor move to next postion\r\n'
# b'Type cdon -turns on postion data when moving will increase time of step\r\n'
# b'Type x0\r\n'
# b'Type mx\r\n'
# b'Type s+Number(0-2000) eg s500 -to set Microseconds betwean steps\r\n'
# b'Type s2000\r\n'
# b'Type x300\r\n'
# b'Type mx\r\n'
# b'Type xoff -turns TB6600 off\r\n'
#
#
# b'ata when moving\r\n'
# b'Speed=2000\r\n'
#
# Scanner fully initialized.

# %%
sc.cam_shot('./photos', 'test_shot_pear')
# Out:
# Copying image to ./photos/test_shot_pear.JPEG

# %%
sc.scan_process('./photos', 'pear_1', 15)
# Out:
# Enter a name for the scanning position: upside_mid
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_15.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_30.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_45.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_60.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_75.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_90.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_105.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_120.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_135.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_150.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_165.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_180.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_195.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_210.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_225.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_240.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_255.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_270.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_285.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_300.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_315.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_330.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_345.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/pear_1_360.JPEG
# b'ENAXOFF\r\n'
# b'Speed=2000\r\n'
# b'ENAXON\r\n'
# Ready to take a backgound photo? (y/n) y
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_mid/background.JPEG
# Continue with another 360deg scan? (y/n) y
# Enter a name for the scanning position: side_mid
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_15.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_30.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_45.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_60.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_75.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_90.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_105.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_120.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_135.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_150.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_165.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_180.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_195.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_210.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_225.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_240.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_255.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_270.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_285.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_300.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_315.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_330.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_345.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/pear_1_360.JPEG
# b'ENAXOFF\r\n'
# b'Speed=2000\r\n'
# b'ENAXON\r\n'
# Ready to take a backgound photo? (y/n) y
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_mid/background.JPEG
# Continue with another 360deg scan? (y/n) upside_high
# Enter a name for the scanning position: upside_high
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_15.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_30.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_45.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_60.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_75.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_90.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_105.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_120.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_135.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_150.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_165.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_180.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_195.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_210.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_225.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_240.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_255.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_270.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_285.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_300.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_315.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_330.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_345.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/pear_1_360.JPEG
# b'ENAXOFF\r\n'
# b'Speed=2000\r\n'
# b'ENAXON\r\n'
# Ready to take a backgound photo? (y/n) y
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/upside_high/background.JPEG
# Continue with another 360deg scan? (y/n) y
# Enter a name for the scanning position: side_high
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_15.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_30.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_45.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_60.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_75.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_90.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_105.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_120.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_135.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_150.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_165.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_180.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_195.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_210.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_225.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_240.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_255.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_270.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_285.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_300.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_315.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_330.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_345.JPEG
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/pear_1_360.JPEG
# b'ENAXOFF\r\n'
# b'Speed=2000\r\n'
# b'ENAXON\r\n'
# Ready to take a backgound photo? (y/n) y
# Copying image to /home/nixi/Desktop/my_projects/scanning_rig/photos/pear_1/photos/side_high/background.JPEG
# Continue with another 360deg scan? (y/n) n
# Finished scan.

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
images = []

for img_path in glob.glob('./photos/pear_1/photos/*/*.JPEG'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(100,50))
columns = 4
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
